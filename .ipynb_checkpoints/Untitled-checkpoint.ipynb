# %% [markdown]
# ## Fundamentals of Data Analysis Project

# %% [markdown]
# ** Investigation and Explanation of the Box Plot**

# %% [markdown]
# A Box Plot, also referred to as a box and whisker plot is a tool for visually displaying data. The box plot can incorporate seven data components that can be contained within the data to be represented;
#
# - Outliers
# - Lower Extreme
# - Lower Whisker
# - Lower Quartile
# - Median
# - Upper Quartile
# - Upper Whisker
# - Upper Extreme
#
# The whiskers represent the variability within the data set that is outside the upper and lower quartiles. The whiskers extend from the ends of the lower and upper quartiles. Outliers are determined to be an observation that lies an abnormal distance from other values in a random sample from a population. How the abnormal distance is calculated is what has to be determined as eliminating data based on the theory that it is an outlier may bias the data if the data point is not truely an outlier.
#
# Box plots can either be represented in vertical or horizontal format as per the graphical representation below.
#
# ![verticalboxplot.png](attachment:verticalboxplot.png) ![horizontalboxplot.png](attachment:horizontalboxplot.png)

# %% [markdown]
# Boxplot
# A graphical summary of the distribution of a sample that shows its shape, central tendency, and variability.
#
# The default boxplot display consists of the following:
#
#
#  1    Outlier (*) - Observation that is beyond the upper or lower whisker
#
# 2    Upper whisker - Extends to the maximum data point within 1.5 box heights from the top of the box
#
# 3    Interquartile range box -  Middle 50% of the data
#
# ·    Top line - Q3 (third quartile). 75% of the data are less than or equal to this value.
#
# ·     Middle line - Q2 (median). 50% of the data are less than or equal to this value.
#
# ·     Bottom line - Q1 (first quartile). 25% of the data are less than or equal to this value.
#
# 4    Lower whisker - Extends to the minimum data point within 1.5 box heights from the bottom of the box
#
#
# Boxplots can help you understand your distribution. For example, the boxplot above represents hold times for customer support calls. The outlier at the upper end and longer upper whisker and upper part of the box indicate positive skewness, which makes sense because at the lower end of the distribution, no hold times can be less than zero.
#
# Boxplots are also useful for comparing several distributions. For example, a quality engineer compares the diameter of plastic pipes produced weekly over three weeks. The boxplot below represents the results.
#
#
#
#
# The medians for the three weeks are similar. However, the boxplots show a tendency for some higher pipe diameters over time.
#
#
#
#
# Boxplots display interquartile range boxes by default, but for some boxplots you can choose to display a different box type:
#
# ·    Median confidence interval box - shows the 95% confidence interval (by default) for the median.
#
# ·    Range box - extends from the minimum value to the maximum value.
